# %% [markdown]
# # Lite Image Viewer
# - Modified from "clicking" template: https://github.com/idchiang/templates/blob/master/clicking/clicking.py
# - Action items
#   - Change to GridSpec
#   - Adopt for image cube
#   - Other to do's on Notion

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

from importlib import reload
from image_viewer_lite import clicking
reload(clicking)

plt.close('all')
plt.switch_backend('Qt5Agg')
matplotlib.interactive(True)

do_things_ngc0628 = True

# Naive examples
test_map = np.random.rand(10, 20)  # for 2D tests
test_cube = np.random.rand(10, 20, 30)  # for 3D tests

# Example cube: THINGS NGC628 NA
if do_things_ngc0628:
    filename = 'C:/Users/jiang/Downloads/NGC_628_NA_CUBE_THINGS.FITS'
    hdu = fits.open(filename)
    sample_data = hdu[0].data[0].copy()
    sample_header = hdu[0].header
    hdu.close()

# Call module
pointmover = clicking.PointMover(data_cube=sample_data, logscale=False, header=sample_header)
# Out:
# g:\我的雲端硬碟\Colab Notebooks\image_viewer_lite\image_viewer_lite\clicking.py:209: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if self.zunit is not 'unidentified_keyword':
# g:\我的雲端硬碟\Colab Notebooks\image_viewer_lite\image_viewer_lite\clicking.py:120: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   self.ax_main.set_xticklabels(xlabels, rotation=30)
# g:\我的雲端硬碟\Colab Notebooks\image_viewer_lite\image_viewer_lite\clicking.py:126: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   self.ax_main.set_yticklabels(ylabels)
# g:\我的雲端硬碟\Colab Notebooks\image_viewer_lite\image_viewer_lite\clicking.py:239: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   self.ax_1.set_xticklabels(xlabels, rotation=30)
# ...
